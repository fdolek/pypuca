# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from statistics import mean
import math
from math import log
import numpy as np
import matplotlib.pyplot as plt


from pylab import rcParams
rcParams['figure.figsize'] = 30, 20

# %%
import pandas as pd
import os
import glob
import numpy as geek 
df = pd.read_csv('~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V-2019-12-14_18-05-55.csv')
df
# Out:
# /home/furkan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            Event      Header  PacketLength  ChannelID     SyncDelay  PeakSum  \
# 0              0  0XAAAAAAAA        1012.0        0.0  1.073732e+09  49958.0
# 1              1  0XAAAAAAAA        1012.0        1.0  1.073732e+09  49226.0
# 2              2  0XAAAAAAAA        1012.0        2.0  1.073732e+09  47882.0
# 3              3  0XAAAAAAAA        1012.0        3.0  1.073732e+09  54096.0
# 4              4  0XAAAAAAAA        1012.0        8.0  1.073732e+09  22146.0
# ...          ...         ...           ...        ...           ...      ...
# 99996      99996  0XAAAAAAAA        1012.0        8.0  1.073732e+09  15894.0
# 99997      99997  0XAAAAAAAA        1012.0        9.0  1.073732e+09  15934.0
# ...

# %%
import pickle

x=df['Baseline'].to_numpy()
x = x[~np.isnan(x)] 
arr = x.reshape(12500, 8)
arr.shape

output = open('base.pkl', 'wb')
pickle.dump(arr, output, protocol=pickle.HIGHEST_PROTOCOL)
output.close()

# %%
g=df.groupby('ChannelID')
g

# %%
for ChannelID, ChannelID_df in g:
    print(ChannelID)
    print(ChannelID_df)
# Out:
# 0.0
#        Event      Header  PacketLength  ChannelID     SyncDelay   PeakSum  \
# 0          0  0XAAAAAAAA        1012.0        0.0  1.073732e+09   49958.0
# 8          8  0XAAAAAAAA        1012.0        0.0  1.073732e+09   15533.0
# 16        16  0XAAAAAAAA        1012.0        0.0  1.073732e+09  163830.0
# 24        24  0XAAAAAAAA        1012.0        0.0  1.073732e+09   16973.0
# 32        32  0XAAAAAAAA        1012.0        0.0  1.073732e+09   18565.0
# ...      ...         ...           ...        ...           ...       ...
# 99960  99960  0XAAAAAAAA        1012.0        0.0  1.073732e+09   16877.0
# 99968  99968  0XAAAAAAAA        1012.0        0.0  1.073732e+09   27827.0
# 99976  99976  0XAAAAAAAA        1012.0        0.0  1.073732e+09   15418.0
# 99984  99984  0XAAAAAAAA        1012.0        0.0  1.073732e+09   22782.0
# 99992  99992  0XAAAAAAAA        1012.0        0.0  1.073732e+09   32801.0
#
#        PeakTime   Prerise  IntegratedSum  Baseline  ...  IntTimestamp2  \
# ...

# %%
x=g.get_group(0.0).to_numpy()

# %%
g.max()
# Out:
#                Header  PacketLength     SyncDelay   PeakSum  PeakTime  \
# ChannelID
# 0.0        0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
# 1.0        0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
# 2.0        0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
# 3.0        0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
# 8.0        0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
# 9.0        0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
# 10.0       0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
# 11.0       0XAAAAAAAA        1012.0  1.073732e+09  163830.0      14.0
#
#             Prerise  IntegratedSum  Baseline  CFDPoint0  CFDPoint1  ...  \
# ChannelID                                                           ...
# 0.0        327660.0        32766.0    6150.0    29112.0    28342.0  ...
# 1.0        327660.0        32766.0    6093.0    28993.0    29457.0  ...
# ...

# %%
g.min()
# Out:
#                Header  PacketLength     SyncDelay  PeakSum  PeakTime  Prerise  \
# ChannelID
# 0.0        0XAAAAAAAA        1012.0  1.073732e+09  15294.0     -58.0  30665.0
# 1.0        0XAAAAAAAA        1012.0  1.073732e+09  15040.0     -58.0  30375.0
# 2.0        0XAAAAAAAA        1012.0  1.073732e+09  15337.0     -58.0  30864.0
# 3.0        0XAAAAAAAA        1012.0  1.073732e+09  15269.0     -58.0  30594.0
# 8.0        0XAAAAAAAA        1012.0  1.073732e+09  15127.0     -58.0  30671.0
# 9.0        0XAAAAAAAA        1012.0  1.073732e+09  15151.0     -58.0  30688.0
# 10.0       0XAAAAAAAA        1012.0  1.073732e+09  15396.0     -58.0  30819.0
# 11.0       0XAAAAAAAA        1012.0  1.073732e+09  15223.0     -58.0  30507.0
#
#            IntegratedSum  Baseline  CFDPoint0  CFDPoint1  ...  IntTimestamp2  \
# ChannelID                                                 ...
# 0.0               3055.0    6103.0   -11828.0   -11230.0  ...            1.0
# ...

# %%
g.mean()
# Out:
#            PacketLength     SyncDelay      PeakSum  PeakTime      Prerise  \
# ChannelID
# 0.0              1012.0  1.073732e+09  23966.72136 -10.48704  53042.51376
# 1.0              1012.0  1.073732e+09  24416.50144 -13.30552  51551.32256
# 2.0              1012.0  1.073732e+09  24231.55024 -21.81032  50860.13272
# 3.0              1012.0  1.073732e+09  25268.84752 -15.65712  54362.26464
# 8.0              1012.0  1.073732e+09  17253.72928 -11.06304  35876.97384
# 9.0              1012.0  1.073732e+09  16997.82336 -10.36440  35696.70184
# 10.0             1012.0  1.073732e+09  17099.15472 -11.25992  35114.29856
# 11.0             1012.0  1.073732e+09  17208.22752 -10.00688  35917.06016
#
#            IntegratedSum    Baseline  CFDPoint0  CFDPoint1  CFDPoint2  ...  \
# ChannelID                                                              ...
# 0.0           5374.37616  6141.43360  218.35840  302.03200  387.00016  ...
# ...

# %%
g.describe()
# Out:
#           PacketLength                                                       \
#                  count    mean  std     min     25%     50%     75%     max
# ChannelID
# 0.0            12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
# 1.0            12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
# 2.0            12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
# 3.0            12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
# 8.0            12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
# 9.0            12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
# 10.0           12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
# 11.0           12500.0  1012.0  0.0  1012.0  1012.0  1012.0  1012.0  1012.0
#
#           SyncDelay                ...    Info.mean            Info.stdDev  \
#               count          mean  ...          75%        max       count
# ChannelID                          ...
# ...

# %%
# %matplotlib inline

# %%
g.plot('Baseline')
# Out:
# ChannelID
# 0.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 1.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 2.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 3.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 8.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 9.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 10.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 11.0    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
g.mean
g.plot(x='Event',y='Baseline')
# Out:
# ChannelID
# 0.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 1.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 2.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 3.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 8.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 9.0     AxesSubplot(0.125,0.125;0.775x0.755)
# 10.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 11.0    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
ch0=g.get_group(0.0)
ch0.plot(y='PeakTime',xlim=(0,1000))

# %%
ch0=g.get_group(0.0)
ch0.plot(y='Baseline', xlim=(0,10000))

# %%
ch0=g.get_group(0.0)
#print(ch0)
ch0.plot(y='Info.mean',xlim=(0,1000))

# %%
ch0=g.get_group(0.0)
#print(ch0)
ch0.plot(x='Event',y='Info.stdDev',xlim=(0,200))

# %%
ch0=g.get_group(0.0)
ch0.plot(x='Event',y='Baseline',xlim=(0,2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-31e92fa44046> in <module>
#       1 ch0=g.get_group(0.0)
# ...

# %% [markdown]
# # A simple plot with a custom dashed line
#
#
# A Line object's ``set_dashes`` method allows you to specify dashes with
# a series of on/off lengths (in points).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from statistics import mean
import math
from math import log
import numpy as np
import matplotlib.pyplot as plt


from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
filelist = []
filelist = ['/home/furkan/work/flicanalyzer/waveform/2019-12-20_17-34-24/Cosmic_Vertical_VBias47V_30ppmXe_NDoping_Ch0-2019-12-20_17-34-24.dat']
#filelist = ['~/work/flicanalyzer/waveform/led/Test_LED_roomTemp_VBias54V.dat_Ch0-2019-12-12_18-06-32.dat']
#filelist = ['~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch0-2019-12-14_18-05-55.dat']
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch1-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch2-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch3-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch8-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch9-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch10-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch11-2019-12-14_18-05-55.dat']
fil=pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in filelist], axis=1)
x = pd.DataFrame(fil).to_numpy()
print(x.shape)
#t=fil.index.to_numpy() #this is not necessary
# Out:
# (11316184, 1)

# %%
s=np.transpose(x)
print(s.shape)
Nevent=int(s.size/2024)
print(Nevent)
print(s)
arr=s.reshape(Nevent,2024)
arr.shape
# Out:
# (1, 11316184)
# 5591
# [[43690 43690  1012 ...  1534  1537  1529]]
# (5591, 2024)

# %%
test=np.delete(arr, np.s_[0:24], axis=1) 

print(test.shape)
#a=test-1500
#a=test
tot=test.sum(axis=0)
# Out:
# (5591, 2000)

# %%
plt.plot(test[3])
plt.title('2019-12-14_18-05-55')
plt.title('firt event', loc='left')
plt.title('Xarapuca Ch0', loc='right')
#plt.yscale('log')

#plt.xlim(250, 1000)
plt.show()

# %%
plt.plot(tot)
plt.yscale('log')
plt.title('2019-12-14_18-05-55')
plt.title('all event', loc='left')
plt.title('Xarapuca Ch0', loc='right')
#plt.xlim(300, 1000)

plt.show()

# %%
n, bins, patches = plt.hist(tot, 500, density=False, facecolor='g', alpha=1)

plt.xlabel('time')
plt.ylabel('amp')
plt.title('probabiliyt')
plt.yscale('log')

plt.grid(True)
plt.show()

# %%
plt.hist(a[1], bins =100) 
plt.title("histogram") 
plt.show()

# %%
from root_numpy import root2array, root2rec
#arry=test-1500
#rnp.fill_profile(profile, array, weights=None, return_indices=False)
