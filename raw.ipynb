# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from statistics import mean
import math
from math import log
import numpy as np
import matplotlib.pyplot as plt

from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
import pandas as pd
import os
import glob
import numpy as geek 
filelist = []
filelist = ['~/work/flicanalyzer/waveform/2020-02-06_13-34-38/Test0_ProtoDune_LAr_Ch1-2020-02-06_13-34-38.dat']
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch1-2019-12-14_18-05-55.dat']
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch2-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch3-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch8-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch9-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch10-2019-12-14_18-05-55.dat',
            #'~/work/flicanalyzer/waveform/2019-12-14_18-05-55/Cosmic_Vertical_VBias47V_Ch11-2019-12-14_18-05-55.dat']
fil=pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in filelist], axis=1)
x = pd.DataFrame(fil).to_numpy()
x
s1=np.transpose(x)
s = s1.ravel()

#x=geek.nan_to_num(x1)
#aver=np.average(x)
#print(aver)
t=fil.index.to_numpy() #this is not necessary
print(s.size/2000)
print(t.size)
# Out:
# 26702.0
# 53404000

# %%
plt.plot(t,s)
plt.axis([0, 30000, 1400, 1850])
#plt.xlim(20, 30)
#plt.yscale('log')
#plt.ylim(0, 100)

plt.show()

# %%
#from scipy import signal
#a=signal.detrend(x).max() < 0.0001

n_bins = 1000

print(x)
fig, axes = plt.subplots(nrows=2, ncols=1)
ax1, ax2, = axes.flatten()
#from scipy import signal
#a=signal.detrend(s).max() < 0.0001

#ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors ,log=True)
#ax0.legend(prop={'size': 10})
#ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=False, histtype='bar', stacked=True ,log=True)
ax1.set_title('stacked bar')
ax1.set_xlim(0, 10000)
ax2.hist(x, n_bins, histtype='step', density=False, stacked=True, fill=False, log=True)
ax2.set_title('stack step (unfilled)')
#ax2.set_xlim(0,10000)
# Make a multiple-histogram of data-sets with different length.
#x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
#ax3.hist(x_multi, n_bins, histtype='bar')
#ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-023cc64cf66c> in <module>
#       4 n_bins = 1000
#       5
# ----> 6 print(x)
#       7 fig, axes = plt.subplots(nrows=2, ncols=1)
#       8 ax1, ax2, = axes.flatten()
#
# NameError: name 'x' is not defined

# %%
import scipy.integrate as integrate
import scipy.special as special
result = integrate.quad(lambda x: special.jv(2.5,x), 0, 4.5)
result
# Out:
# (1.1178179380783253, 7.866317182537226e-09)

# %%
x=df
plt.plot(x,a[1:2].T,'r--',label="x vs y1") #CONTAINS YOUR 3RD ROW
plt.legend(loc='best')
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-42bbe8a7302f> in <module>
# ----> 1 x=df
#       2 plt.plot(x,a[1:2].T,'r--',label="x vs y1") #CONTAINS YOUR 3RD ROW
#       3 plt.legend(loc='best')
#       4 plt.xlabel("x")
#       5 plt.ylabel("y")
#
# NameError: name 'df' is not defined

# %%
x=df
fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1 = axes.flatten()

colors = ['red', 'tan',]
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()

# %%
import pandas as pd
import glob

# Taken from http://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe#comment57648172_21232849

# Read multiple files into one dataframe
allfiles = glob.glob('/home/furkan/work/flicanalyzer/waveform/xar/*.dat')
df = pd.concat((pd.read_csv(f) for f in allfiles))

# Read multiple files into one dataframe whilst adding custom columns
def my_csv_reader(path):
  d = pd.read_csv(path)
  d['Filepath'] = path  # an example of a column to be added to each dataframe
  return d
  
allfiles = glob.glob('/home/furkan/work/flicanalyzer/waveform/xar/*.dat')
df = pd.concat((my_csv_reader(f) for f in allfiles))
print(df)

# %%
s1=df.to_numpy()
s2=np.transpose(s1)
s = s2.ravel()
print(s)
t=df.index.to_numpy() +1 #this is not necessaryplt.hist(s, bins = 250, log=True, histtype='step' )


plt.hist(s, bins = 250, log=True, histtype='step' , color='C0')
plt.ylim((1,10000000))
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-08523afceb99> in <module>
# ----> 1 s1=df.to_numpy()
#       2 s2=np.transpose(s1)
#       3 s = s2.ravel()
#       4 print(s)
#       5 t=df.index.to_numpy() +1 #this is not necessaryplt.hist(s, bins = 250, log=True, histtype='step' )
#
# NameError: name 'df' is not defined

# %%
import os
import glob
my_dir = "/home/furkan/work/flicanalyzer/waveform/xar"
filelist = []
filesList = []
os.chdir( my_dir )

# Step 2: Build up list of files:
for files in glob.glob("*.dat"):
    fileName, fileExtension = os.path.splitext(files)
    filelist.append(fileName) #filename without extension
    filesList.append(files) #filename w
    
df = pd.DataFrame()
for ijk in filelist:
    frame = pd.read_csv(ijk)
    df = df.append(frame)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-43a87ed2a226> in <module>
#      14 df = pd.DataFrame()
#      15 for ijk in filelist:
# ---> 16     frame = pd.read_csv(ijk)
#      17     df = df.append(frame)
#      18 df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Cosmic_Vertical_VBias47V_1from0ppm_alpha_Ch10-2019-12-19_12-29-31' does not exist: b'Cosmic_Vertical_VBias47V_1from0ppm_alpha_Ch10-2019-12-19_12-29-31'

# %%
df = pd.read_csv("~/work/flicanalyzer/waveform/xar/Cosmic_Vertical_VBias47V_1from0ppm_alpha_Ch0-2019-12-19_12-29-31.dat",
                 delim_whitespace=True,)
                 #usecols=[1,])
                 #names=["y",])
#df
s1=df.to_numpy()
s2=np.transpose(s1)
s = s2.ravel()
print(s)
t=df.index.to_numpy() +1 #this is not necessaryplt.hist(s, bins = 250, log=True, histtype='step' )


plt.hist(s, bins = 250, log=True, histtype='step' , color='C0')
plt.ylim((1,10000000))
plt.grid()
plt.show()
# Out:
# [43690  1012     0 ...  1523  1518  1522]

# %%
from scipy import signal
a=signal.detrend(s).max() < 0.0001

plt.hist(s-a, bins = 250, log=True, histtype='bar' , color='C1')
plt.title('noise remove')
plt.ylim((1,10000000))
plt.grid()
plt.show() #yazmanssan matrisi gorursun

# %%
signsq = (1 + 1) / 12.0
bs = 1 / np.sqrt(2 * 3.14 * signsq) * np.exp(-s ** 2 / 2 / signsq)
plt.hist(s-bs, bins = 250, log=True, histtype='bar' , color='C2')
plt.title('baseline')
plt.ylim((1,10000000))
plt.grid()
plt.show()

# %%
signsq = (1 + 1) / 12.0
bs = 1 / np.sqrt(2 * 3.14 * signsq) * np.exp(-s ** 2 / 2 / signsq)
plt.hist(s-bs, bins = 250, log=True, histtype='bar' , color='C2')
plt.title('baseline')
plt.ylim((1,10000000))
plt.grid()
plt.show()
decwelch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ea7ab7eeebaf> in <module>
#       6 plt.grid()
#       7 plt.show()
# ----> 8 decwelch
#       9
#      10
#
# NameError: name 'decwelch' is not defined

# %%
Fs = 1 / t  # sampling frequency
print(Fs)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 15))

# plot time signal:
axes[0, 0].set_title("Signal")
axes[0, 0].plot(t, s, color='C0',linestyle='dashed')
axes[0, 0].set_xlabel("Time")
axes[0, 0].set_ylabel("Amplitude")

# plot different spectrum types:
axes[1, 0].set_title("Magnitude Spectrum")
axes[1, 0].magnitude_spectrum(s, Fs=Fs, color='C1')

axes[1, 1].set_title("Log. Magnitude Spectrum")
axes[1, 1].magnitude_spectrum(s, Fs=Fs, scale='dB', color='C1')

axes[2, 0].set_title("Phase Spectrum ")
axes[2, 0].phase_spectrum(s, Fs=Fs, color='C2')

axes[2, 1].set_title("Angle Spectrum")
axes[2, 1].angle_spectrum(s, Fs=Fs, color='C2')

axes[0, 1].remove()  # don't display empty ax

fig.tight_layout()
plt.show()

# %%
Fs = 1 / t  # sampling frequency



s_mean = [np.mean(s)]*len(t)

# plot time signal:

plt.plot(t, s, color='C0' ,linestyle='dotted')
plt.show()


from scipy.fftpack import fft, ifft
y = fft(a)
yinv = ifft(y)
yinv

from scipy.fftpack import fft
N = 500
T = 1.0/800.0
x = np.linspace(0.0, N*T,N)
y = np.sin(50.0 * 2.0 * np.pi *x) + 0.5 * np.sin(80.0 * 2.0 * np.pi * x)
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N*np.abs(yf[0:N//2]))
plt.grid()
plt.show()

# %%
n, bins, patches = plt.hist(s, 50, density=True, facecolor='g', alpha=1)

plt.xlabel('time')
plt.ylabel('amp')
plt.title('probabiliyt')
plt.yscale('log')

plt.grid(True)
plt.show()

# %%
Fs = 1 / t  # sampling frequency
print(Fs)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 15))

# plot time signal:
axes[0, 0].set_title("Signal")
axes[0, 0].plot(t, s, color='C0',linestyle='dashed')
axes[0, 0].set_xlabel("Time")
axes[0, 0].set_ylabel("Amplitude")

# plot different spectrum types:
axes[1, 0].set_title("Magnitude Spectrum")
axes[1, 0].magnitude_spectrum(s, Fs=Fs, color='C1')

axes[1, 1].set_title("Log. Magnitude Spectrum")
axes[1, 1].magnitude_spectrum(s, Fs=Fs, scale='dB', color='C1')

axes[2, 0].set_title("Phase Spectrum ")
axes[2, 0].phase_spectrum(s, Fs=Fs, color='C2')

axes[2, 1].set_title("Angle Spectrum")
axes[2, 1].angle_spectrum(s, Fs=Fs, color='C2')

axes[0, 1].remove()  # don't display empty ax

fig.tight_layout()
plt.show()
# Out:
# [1.00000000e+00 5.00000000e-01 3.33333333e-01 ... 3.13497215e-07
#  3.13497117e-07 3.13497018e-07]

# %%
from scipy.fftpack import fft, ifft
y = fft(s)
yinv = ifft(y)
yinv

from scipy.fftpack import fft
N = 500
T = 1.0/800.0
x = np.linspace(0.0, N*T,N)
y = np.sin(50.0 * 2.0 * np.pi *x) + 0.5 * np.sin(80.0 * 2.0 * np.pi * x)
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N*np.abs(yf[0:N//2]))
plt.grid()
plt.show()
